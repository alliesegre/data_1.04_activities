# %%
import pandas as pd

# %%
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
file1 = pd.read_csv('/Users/segre/OneDrive/Desktop/IRONHACK/13.01.21/data_1.04_activities/files_for_activities/csv_files/file1.csv')

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
file1[file1['IC4'].isna()==True]
# Out:
#     CONTROLN STATE GENDER  HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2    IC2  \
# 20     41384    FL      F  556  318  NaN     0  11779     16     22  358.0
#
#     IC3   AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 20  320  9.428571     28  5107     S3      12.0

# %%
file1['IC4'].isna().sum()
# Out:
# 1

# %%
file1['IC4'].dtypes
# Out:
# dtype('float64')

# %%
file1[file1['IC5'].isna()==True]
# Out:
# Empty DataFrame
# Columns: [CONTROLN, STATE, GENDER, HV1, IC1, IC4, HVP1, IC5, POBC1, POBC2, IC2, IC3, AVGGIFT, TCODE, DOB, DOMAIN, TARGET_D]
# Index: []

# %%
file1['IC5'].isna().sum()
# Out:
# 0

# %%
file1['IC4'] = file1['IC4'].apply(pd.to_numeric, errors='coerce')

file1['IC4'] = file1['IC4'].fillna(file1['IC4'].median())

file1
# Out:
#       CONTROLN       STATE   GENDER      HV1   IC1     IC4  HVP1     IC5  \
# 0        44060          FL        M   AAA896   392   520.0     7   21975
# 1        96093          IL        M   537.00   365   473.0     0   19387
# 2        43333          FL        F   725.00   301   436.0     3   18837
# 3        21885          NC        M  AAA1095   401   413.0     7   14014
# 4       190108          FL        F   995.00   252   348.0     0   17991
# 5       100640          IL        M   764.00   457   501.0     1   16022
# 6        18581          NC   female   775.00   318   419.0     5   13491
# 7       119038          TX        M   890.00   519   560.0     0   17872
# 8       173223          CA        F      NaN   184   250.0     0    8708
# 9       157988          CA        F  AAA2294   593   617.0    61   17838
# 10      141720          NV        F     1569   673   781.0    22   25775
# 11      186272          CA        F     3515   521   588.0    97   20068
# ...

# %%
file1['IC4'].isna().sum()
# Out:
# 0

# %%
file1['IC5'] = pd.to_numeric(file1['IC5'], errors='coerce')

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1      IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975.0      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387.0      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837.0     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014.0      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991.0      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0
